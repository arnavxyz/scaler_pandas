# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavxyz/scaler_pandas/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# pip install pandas

# %%
import numpy as np

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2023-12-21 14:54:11--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.251.170.100, 142.251.170.138, 142.251.170.139, ...
# Connecting to drive.google.com (drive.google.com)|142.251.170.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lt8ce8f69n5sj95hbq90ivl306fm3c4v/1703170425000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=f2967cac-c4eb-4017-8f9e-00a5b56a2a4c [following]
# ...
# --2023-12-21 14:54:12--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lt8ce8f69n5sj95hbq90ivl306fm3c4v/1703170425000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=f2967cac-c4eb-4017-8f9e-00a5b56a2a4c
# ...

# %%
'''
Use Case: Mckinsey wants to understand the relation between GDP per capita and life expectancy and various trends for their clients. Data is acquired from multiple surveys from different countries.
'''
# Out:
# '\nUse Case: Mckinsey wants to understand the relation between GDP per capita and life expectancy and various trends for their clients. Data is acquired from multiple surveys from different countries.\n'

# %%
df = pd.read_csv('mckinsey.csv') # Storing the data in variable df (Pandas Dataframe)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
'''
Pandas Dataframe : A table-like representation of data in Pandas => Structured Data
Structured Data can be thought of as tabular data in a proper data
It is considered as a counterpart of 2D-Matrix in Numpy
'''
# Out:
# '\nPandas Dataframe : A table-like representation of data in Pandas => Structured Data\nStructured Data can be thought of as tabular data in a proper data\nIt is considered as a counterpart of 2D-Matrix in Numpy\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
'''
PLEASE DON'T USE THIS SYNTAX
'''
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
'''
If we are having space in the column name, this syntax will fail
'''
#df.life exp
# Out:
# '\nIf we are having space in the column name, this syntax will fail\n'

# %%
df.columns # Gives column names
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() # Gives column names
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.head() # Gives first 5 rows
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail() #Gives last 5 rows
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country', 'life_exp']].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
type(df[['country', 'life_exp']])
# Out:
# pandas.core.frame.DataFrame

# %%
'''
Series in pandas is exactly similar to vector in numpy. It is a single column of data.
Multiple series when stacked together forms a dataframe
'''
# Out:
# '\nSeries in pandas is exactly similar to vector in numpy. It is a single column of data.\nMultiple series when stacked together forms a dataframe\n'

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].value_counts() # Gives output in decreasing order of frequency
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df.rename({"population": "POPULATION"}, axis=1) # Not an inplace operation
# Out:
#           country  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"population": "POPULATION"}, axis=1, inplace=True)

# %%
df
# Out:
#           country  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns = {"population": "POPULATION"})
# Out:
#           country  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"country": "COUNTRY", "life_exp": "Life_Exp"}, axis=1, inplace=True)

# %%
df
# Out:
#           COUNTRY  year  POPULATION continent  Life_Exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent', axis=1)
# Out:
#           COUNTRY  year  POPULATION  Life_Exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop(columns=['continent'])
# Out:
#           COUNTRY  year  POPULATION  Life_Exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
'''
df.drop(df.columns[-3], axis=1)
'''
# Out:
# '\ndf.drop(df.columns[-3], axis=1)\n'

# %%
'''
Q1. Correct way to form a dataframe?
'''
# option a
df = pd.DataFrame([[1, 2], ["Ram", "Shyam"], ["IT", "Ops"]], columns = ["emp_id", "name", "dept"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     968     try:
# --> 969         columns = _validate_or_indexify_columns(contents, columns)
#     970     except AssertionError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#    1016             # caller's responsibility to check for this...
# -> 1017             raise AssertionError(
#    1018                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# option b
df = pd.DataFrame([[1, "Ram", "IT"], [2, "Shyam", "Ops"]], columns = ["emp_id", "name", "dept"])
df.head()
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
# option c

df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3c3230e49a6a> in <cell line: 3>()
#       1 # option c
#       2
# ----> 3 df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
#       4 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     760                     )
#     761                 else:
# --> 762                     mgr = ndarray_to_mgr(
#     763                         data,
#     764                         index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# --> 349     _check_values_indices_shape_match(values, index, columns)
#     350
#     351     if typ == "array":
#
# ...

# %%
#option d

df = pd.DataFrame({'emp_id':[1, 2], 'name': ['Ram', 'Shyam'], 'dept':['IT', 'Ops']})
df.head()

#Ans: option b, d
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
'''
Q2. First 20

Which of the following options will return the first 20 rows of a given dataframe df?


a. df.head()

b. df.head(20)

c. df.tail(20)

d. df.iloc[:20]
'''

# Ans: b, d
# Out:
# '\nQ2. First 20\n\nWhich of the following options will return the first 20 rows of a given dataframe df?\n\n\na. df.head()\n\nb. df.head(20)\n\nc. df.tail(20)\n\nd. df.iloc[:20]\n'

# %%
'''
Q3. Be unique

Which of the following statements are true?

a. .unique() method returns unique values in a Series.

b. .unique(), when applied on a dataframe returns unique values for each column.

c. .nunique() method returns the count of unique elements in a Series.

d. .nunique(), when applied on a dataframe returns the number of unique elements for each column.

'''

#Ans: a, c, d
# Out:
# '\nQ3. Be unique\n\nWhich of the following statements are true?\n\na. .unique() method returns unique values in a Series.\n\nb. .unique(), when applied on a dataframe returns unique values for each column.\n\nc. .nunique() method returns the count of unique elements in a Series.\n\nd. .nunique(), when applied on a dataframe returns the number of unique elements for each column.\n\n'

# %%
'''
Q4. Data Extraction

Given the following data frame "df", which of the following command(s) is/are the correct way to extract the mentioned columns in the order: time, total_bill, tip?

a. pd.DataFrame(df, columns=['time', 'total_bill', 'tip'])

b. df[['time', 'total_bill', 'tip']]

c. df.loc[:, ['time', 'total_bill', 'tip']]

d. df.iloc[:,0:2]
'''

# Ans: a, b, c
# Out:
# '\nQ4. Data Extraction\n\nGiven the following data frame "df", which of the following command(s) is/are the correct way to extract the mentioned columns in the order: time, total_bill, tip?\n\na. pd.DataFrame(df, columns=[\'time\', \'total_bill\', \'tip\'])\n\nb. df[[\'time\', \'total_bill\', \'tip\']]\n\nc. df.loc[:, [\'time\', \'total_bill\', \'tip\']]\n\nd. df.iloc[:,0:2]\n'

# %%
''''
Q5. loc and iloc

From the above-given information, mark the option which is true regarding the following statements.

1. For line a, the output is the first two rows with the three columns ["Name", "Gender", "Profession"].

2. For line a, the output is the first two rows with the two columns ["Name", "Gender"].

3. For line b, the output is the row with labels 0, 1, and 2 with the columns ["Name", "Gender", "Profession"].

4. For line b, TypeError will be generated.
'''

df = pd.DataFrame({'name': ['Jim', 'Carrey', 'Chris', 'Morris'], 'gender':['M', 'F', 'M', 'M'], 'profession':['Athlete', 'Tech', 'Cricketer', 'Actor']})
df.head()
# Out:
#      name gender profession
# 0     Jim      M    Athlete
# 1  Carrey      F       Tech
# 2   Chris      M  Cricketer
# 3  Morris      M      Actor

# %%
df.iloc[:2,:2]                           #line a
# Out:
#      name gender
# 0     Jim      M
# 1  Carrey      F

# %%
df.loc[:2,"name":"profession"]           #line b

# Ans: Only statements 2 and 3 are true.
# Out:
#      name gender profession
# 0     Jim      M    Athlete
# 1  Carrey      F       Tech
# 2   Chris      M  Cricketer

# %%
'''
Q6. Select the required data

Given the dataset of 10 car models and their respective features:

What would be the correct code to get the resultant subset as the below image?
'''

import statsmodels.api as sm
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.stats import anova

mtcars = sm.datasets.get_rdataset("mtcars", "datasets", cache=True).data
df_cars = pd.DataFrame(mtcars)
df_cars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# rownames
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# rownames
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
df_cars.iloc[1:5, 3:5] # Correct Ans is option a.
# Out:
#                     hp  drat
# rownames
# Mazda RX4 Wag      110  3.90
# Datsun 710          93  3.85
# Hornet 4 Drive     110  3.08
# Hornet Sportabout  175  3.15
