# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavxyz/scaler_pandas/blob/main/module_test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.arange(34,67)
len(arr)
# Out:
# 33

# %%
sum(arr)
# Out:
# 1650

# %%
import pandas as pd
link = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/033/327/original/flights.csv?1683012330"
df = pd.read_csv(link)

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sorted_df = df.sort_values(by='passengers', ascending = False)
sorted_df.head()
# Out:
#      year month  passengers
# 138  1960   Jul         622
# 139  1960   Aug         606
# 127  1959   Aug         559
# 126  1959   Jul         548
# 137  1960   Jun         535

# %%
odds = np.arange(1, 10, 2)
evens = np.arange(2, 11, 2)
stacked_arr = np.vstack((odds, evens))
stacked_arr.shape
# Out:
# (2, 5)

# %%
stacked_arr
# Out:
# array([[ 1,  3,  5,  7,  9],
#        [ 2,  4,  6,  8, 10]])

# %%
np.array((7, 8, 9, 10)).mean()
# Out:
# 8.5

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df.head()
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_filtered = df[(df['total_bill'] > 20) & (df['tip'] > 4)]
df_filtered.describe()
# Out:
#        total_bill        tip       size
# count   37.000000  37.000000  37.000000
# mean    31.655676   5.450000   3.675676
# std      8.482144   1.272932   1.248422
# min     20.490000   4.060000   2.000000
# 25%     25.280000   4.730000   3.000000
# 50%     29.930000   5.000000   4.000000
# 75%     35.260000   5.850000   4.000000
# max     50.810000  10.000000   6.000000

# %%
hstacked_arr = np.hstack((evens, odds))
hstacked_arr.reshape(2, 5)
# Out:
# array([[ 2,  4,  6,  8, 10],
#        [ 1,  3,  5,  7,  9]])

# %%
np.mean(hstacked_arr[[1]])
# Out:
# 4.0

# %%
sum(np.arange(1, 21).reshape(10, 2)[:,1] ** 2)
# Out:
# 1540
