# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavxyz/scaler_pandas/blob/main/DAV1_Problem_Solving_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
typ = ['Desktop', 'Laptop', 'Tablet', 'Desktop', 'Desktop', 'Desktop', 'Desktop', 'Desktop', 'Laptop', 'Laptop', 'Tablet', 'Tablet', 'Laptop', 'Laptop', 'Tablet', 'Laptop', 'Laptop', 'Tablet', 'Tablet', 'Desktop']
src = ['Poster 1', 'Poster 4', 'Poster 4', 'Email', 'Poster 4', 'Poster 2', 'Poster 1', 'Poster 3', 'Poster 4', 'Poster 4', 'Poster 3', 'Poster 3', 'Website', 'Poster 3', 'Poster 2', 'Poster 1', 'Website', 'Website', 'Poster 1', 'Poster 3']
df = pd.DataFrame({'Product Type': typ, 'Source': src})
df
# Out:
#    Product Type    Source
# 0       Desktop  Poster 1
# 1        Laptop  Poster 4
# 2        Tablet  Poster 4
# 3       Desktop     Email
# 4       Desktop  Poster 4
# 5       Desktop  Poster 2
# 6       Desktop  Poster 1
# 7       Desktop  Poster 3
# 8        Laptop  Poster 4
# 9        Laptop  Poster 4
# 10       Tablet  Poster 3
# 11       Tablet  Poster 3
# 12       Laptop   Website
# 13       Laptop  Poster 3
# 14       Tablet  Poster 2
# 15       Laptop  Poster 1
# 16       Laptop   Website
# 17       Tablet   Website
# 18       Tablet  Poster 1
# 19      Desktop  Poster 3

# %%
sns.countplot(x = 'Source', data =df)
# Out:
# <Axes: xlabel='Source', ylabel='count'>

# %%
l = [4, 3, 4, 4, 2, 2, 2, 3, 2, 3, 1, 6, 1, 3, 1, 2, 2, 1, 1, 3, 3, 2, 2, 2, 2, 1, 3, 3, 3, 1, 2, 1, 3, 3, 3, 1, 3, 1, 2, 3, 2, 4, 2, 4, 4, 4, 3, 2, 2, 3, 3, 3, 3, 3, 1, 2, 4, 5, 3, 3, 2, 1, 2, 2, 3, 3, 2, 6, 2, 2, 3, 3, 2, 1, 3, 3, 2]

# %%
np.unique(l, return_counts =True)
# Out:
# (array([1, 2, 3, 4, 5, 6]), array([13, 25, 28,  8,  1,  2]))

# %%
# What output i need
d = {i:l.count(i) for i in l}
x = []
y = []
for i, j in sorted(list(d.items()), key = lambda x:x[0]):
  x.append(i)
  y.append(j)

# %%
sorted(list(d.items()), key = lambda x:x[0])
# Out:
# [(1, 13), (2, 25), (3, 28), (4, 8), (5, 1), (6, 2)]

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
y
# Out:
# [8, 28, 25, 13, 2, 1]

# %%
sns.barplot(x = x, y = y, color = 'g')
# Out:
# <Axes: >

# %%
df = pd.Series(l).value_counts().reset_index().sort_values("index")
x = df['index']
y = df[0]

# %%
list(x)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list(y)
# Out:
# [13, 25, 28, 8, 1, 2]

# %%
sns.barplot(x = x, y = y, color = 'green')
# Out:
# <Axes: xlabel='index', ylabel='0'>

# %%
plt.bar(x, y, color = 'g')
# Out:
# <BarContainer object of 6 artists>

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.kdeplot(x = "age", data =df)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(x = "age", data =df)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x = "sex", y = 'age', hue = 'survived', data =df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x = "sex", y = 'age', hue = 'survived', data =df, estimator = 'mean')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# violinplot: Boxplot+KDE (Density Distribution)
sns.violinplot(x = "sex", y = 'age', hue = 'survived', data =df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.histplot?

# %%
sns.histplot(x = "age", data = df, binwidth = 20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
w = df[(df['sex']=='female') & (df['age']<60) & (df['survived']==1)]
sns.histplot(x = "age", data = w, binwidth = 20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.barplot(x = 'sex', y = 'survived', estimator = lambda x: (sum(x)*100)/len(x), data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.countplot(x = 'survived', hue = 'sex', data  = df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x = 'class', hue = 'survived', data  = df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df.groupby("class").agg(mean_fare = ("fare", 'mean'), median_fare = ("fare", 'median')).plot(kind = 'bar')
# Out:
# <Axes: xlabel='class'>

# %%
sns.boxplot(x = "class", y = "fare", hue = 'survived', data =df[(df['class']=='Second')])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.violinplot(x = "class", y = "fare", hue = 'survived', data =df[(df['class']=='Second')])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
df[(df['pclass']==2) & (df['fare']> 60)]['survived'].value_counts()
# Out:
# 0    5
# 1    2
# Name: survived, dtype: int64

# %%
sns.barplot(x = "class", y = 'fare', hue = 'survived', data =df, estimator = 'mean')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
ax = sns.countplot(x = 'class', hue = 'survived', data  = df)
for i in ax.containers:
  ax.bar_label(i)

# %%
ax = sns.countplot(x = 'class', data  = df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '216'), Text(0, 0, '184'), Text(0, 0, '491')]

# %%
ax
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
ax.containers[0]
# Out:
# <BarContainer object of 3 artists>

# %%
ax = sns.histplot(x = "age", data =df)
for i in ax.containers:
  ax.bar_label(i)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
l = []
for i, j in list(zip(df['sex'], df['survived'])):
  l.append(i+str(j))

# %%
df['Sex_Survived'] = l

# %%
df['Sex_Survived'].value_counts()
# Out:
# male0      468
# female1    233
# male1      109
# female0     81
# Name: Sex_Survived, dtype: int64

# %%
sns.scatterplot(x = 'fare', y = "age", hue = "Sex_Survived", data  = df)
# Out:
# <Axes: xlabel='fare', ylabel='age'>
